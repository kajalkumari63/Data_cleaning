# %% [markdown]
# # Task 3

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploraing Datasets

# %%
df = pd.read_csv("D:/data cleaning/AB_NYC_2019.csv")

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
for column in df.columns:
    if df[column].isnull().sum() !=0:
        print(f'{column} --> Missing Values: {df[column].isnull().sum()}, dtypes: {df[column].dtypes}')
# Out:
# name --> Missing Values: 16, dtypes: object
# host_name --> Missing Values: 21, dtypes: object
# last_review --> Missing Values: 10052, dtypes: object
# reviews_per_month --> Missing Values: 10052, dtypes: float64

# %%
df['last_review'] = pd.to_datetime(df.last_review)

# %%
df.last_review.isnull().sum()
# Out:
# 10052

# %%
df['reviews_per_month'] = df['reviews_per_month'].fillna(df['reviews_per_month'].mean())

# %%
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 48890         NaT           1.373221                               2
# 48891         NaT           1.373221                               2
# 48892         NaT           1.373221                               1
# 48893         NaT           1.373221                               6
# 48894         NaT           1.373221                               1
#
#        availability_365
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23

# %%
df.last_review.fillna(method = "ffill", inplace = True)

# %%
for i in df.columns:
    if df[i].isnull().sum() !=0:
        print(f'{i} --> Missing Values: {df[i].isnull().sum()}, dtypes: {df[i].dtypes}')
# Out:
# name --> Missing Values: 16, dtypes: object
# host_name --> Missing Values: 21, dtypes: object

# %%
for column in df.columns:
    if df[column].isnull().sum() != 0:
        df[column] = df[column].fillna(df[column].mode()[0])

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   938
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    48895.000000       48895.000000                          48895
# mean         7.029962          23.274466  2018-10-14 06:10:06.540546304
# min          1.000000           0.000000            2011-03-28 00:00:00
# 25%          1.000000           1.000000            2018-07-31 00:00:00
# 50%          3.000000           5.000000            2019-05-25 00:00:00
# 75%          5.000000          24.000000            2019-06-24 00:00:00
# max       1250.000000         629.000000            2019-07-08 00:00:00
# std         20.510550          44.550582                            NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# count       48895.000000                    48895.000000      48895.000000
# mean            1.373221                        7.143982        112.781327
# min             0.010000                        1.000000          0.000000
# 25%             0.280000                        1.000000          0.000000
# 50%             1.220000                        1.000000         45.000000
# 75%             1.580000                        2.000000        227.000000
# max            58.500000                      327.000000        365.000000
# std             1.497775                       32.952519        131.622289

# %%
df.drop(['id', 'host_name'], axis = 'columns', inplace = True )

# %%
df.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19           0.210000
# 1    225               1                 45  2019-05-21           0.380000
# 2    150               3                  0  2019-05-21           1.373221
# 3     89               1                270  2019-07-05           4.640000
# 4     80              10                  9  2018-11-19           0.100000
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
corr = df[['price','minimum_nights','number_of_reviews', 'calculated_host_listings_count',
             'availability_365','latitude','longitude','reviews_per_month']]
corr.corr()
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000        0.042799          -0.047954
# minimum_nights                  0.042799        1.000000          -0.080116
# number_of_reviews              -0.047954       -0.080116           1.000000
# calculated_host_listings_count  0.057472        0.127960          -0.072376
# availability_365                0.081829        0.144303           0.172028
# latitude                        0.033939        0.024869          -0.015389
# longitude                      -0.150019       -0.062747           0.059094
# reviews_per_month              -0.022373       -0.091942           0.530093
#
#                                 calculated_host_listings_count  \
# price                                                 0.057472
# minimum_nights                                        0.127960
# number_of_reviews                                    -0.072376
# calculated_host_listings_count                        1.000000
# availability_365                                      0.225701
# latitude                                              0.019517
# longitude                                            -0.114713
# reviews_per_month                                    -0.006701
#
#                                 availability_365  latitude  longitude  \
# price                                   0.081829  0.033939  -0.150019
# minimum_nights                          0.144303  0.024869  -0.062747
# number_of_reviews                       0.172028 -0.015389   0.059094
# calculated_host_listings_count          0.225701  0.019517  -0.114713
# availability_365                        1.000000 -0.010983   0.082731
# latitude                               -0.010983  1.000000   0.084788
# longitude                               0.082731  0.084788   1.000000
# reviews_per_month                       0.162980 -0.009115   0.131599
#
#                                 reviews_per_month
# price                                   -0.022373
# minimum_nights                          -0.091942
# number_of_reviews                        0.530093
# calculated_host_listings_count          -0.006701
# availability_365                         0.162980
# latitude                                -0.009115
# longitude                                0.131599
# reviews_per_month                        1.000000

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=[10, 8])
sns.heatmap(corr.corr(), annot=True ,fmt = '.2f',annot_kws={"fontsize": 14},linewidths=0.25,center= 0.3,cmap= 'coolwarm',square=True)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)
plt.tight_layout()
plt.show()
# Out:
# D:\kajal\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\KAMDEO SINGH\AppData\Local\Temp\ipykernel_17148\2087484501.py:2: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
brooklyn = df[df['neighbourhood_group'] == 'Brooklyn'].reset_index()
manhattan = df[df['neighbourhood_group'] == 'Manhattan'].reset_index()
queens = df[df['neighbourhood_group'] == 'Queens'].reset_index()
staten_island = df[df['neighbourhood_group'] == 'Staten Island'].reset_index()
bronx = df[df['neighbourhood_group'] == 'Bronx'].reset_index()

brooklyn.drop('index', axis=1, inplace=True)
manhattan.drop('index', axis=1, inplace=True)
queens.drop('index', axis=1, inplace=True)
staten_island.drop('index', axis=1, inplace=True)
bronx.drop('index', axis=1, inplace=True)
bronx.head()
# Out:
#                                                name  host_id  \
# 0                                  Room with a View   190409
# 1                    Cozy bedroom by Yankee Stadium   190409
# 2                                               LL3   295128
# 3  DOMINIQUE'S NY mini efficiency* wifi*metro*quiet   310670
# 4              Condo Apartment with laundry in unit   369015
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0               Bronx    Highbridge  40.83232  -73.93184     Private room
# 1               Bronx    Highbridge  40.83075  -73.93058     Private room
# 2               Bronx  Clason Point  40.81309  -73.85514     Private room
# 3               Bronx   Eastchester  40.88057  -73.83572  Entire home/apt
# 4               Bronx   Kingsbridge  40.87207  -73.90193  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0     40               1                219  2019-07-04           2.040000
# 1     45               1                138  2019-06-30           1.450000
# 2     90               2                  0  2016-08-29           1.373221
# 3    105               2                 38  2019-06-27           0.500000
# 4     90              30                  4  2019-01-02           0.350000
#
#    calculated_host_listings_count  availability_365
# 0                               3               353
# 1                               3               323
# 2                               7               349
# 3                              13               365
# 4                               2               346

# %% [markdown]
# *Outliers Detection*

# %%
def outliers(dataset, columns):
    for column in columns:
        q = dataset[column].quantile(0.95)
        dataset = dataset[dataset[column] < q]
    return dataset

# %%
outliers(brooklyn, ['price', 'number_of_reviews', 'calculated_host_listings_count', 'reviews_per_month'])
outliers(manhattan, ['price', 'number_of_reviews', 'calculated_host_listings_count', 'reviews_per_month'])
outliers(queens, ['price', 'number_of_reviews', 'calculated_host_listings_count', 'reviews_per_month'])
outliers(staten_island, ['price', 'number_of_reviews', 'calculated_host_listings_count', 'reviews_per_month'])
outliers(bronx, ['price', 'number_of_reviews', 'calculated_host_listings_count', 'reviews_per_month'])

brooklyn = brooklyn.loc[brooklyn['minimum_nights'] < brooklyn['minimum_nights'].quantile(0.90)]
manhattan = manhattan.loc[manhattan['minimum_nights'] < manhattan['minimum_nights'].quantile(0.90)]
queens = queens.loc[queens['minimum_nights'] < queens['minimum_nights'].quantile(0.90)]
staten_island = staten_island.loc[staten_island['minimum_nights'] < staten_island['price'].quantile(0.90)]
bronx = bronx.loc[bronx['minimum_nights'] < bronx['minimum_nights'].quantile(0.90)]

# %%
numeric_features = df.select_dtypes(include=["int64","float64"]).columns
categorical_features = df.select_dtypes(include=["object"]).columns
print(numeric_features)
print(categorical_features)
# Out:
# Index(['host_id', 'latitude', 'longitude', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')
# Index(['name', 'neighbourhood_group', 'neighbourhood', 'room_type'], dtype='object')

# %%
def draw_plot(df, val, rows, cols):
    fig, axes = plt.subplots(nrows=rows, ncols=cols)
    aux = 0
    fig.set_figheight(17)
    fig.set_figwidth(25)
    for row in axes:
        for col in row:
            sns.histplot(df, x=val[aux], ax=col)
            col.set_title(val[aux] + " Distribution", fontsize=16, fontweight="bold")
            aux += 1

# Visualizing the distribution for every numeric feature
draw_plot(df, numeric_features, 2, 4)

# %%
df = df[df["price"]>0]
df = df[df["price"]<500]
df = df[df["minimum_nights"]<10]
df = df[df["number_of_reviews"]>0]
df = df[df["number_of_reviews"]<100]
df = df[df["reviews_per_month"]>0]
df = df[df["reviews_per_month"]<10]
df = df[df["calculated_host_listings_count"]<10]

draw_plot(df, numeric_features, 2, 4)

# %%
plt.figure(figsize=(30, 20))
sns.heatmap(df[numeric_features].corr(), annot=True)
# Out:
# <Axes: >

# %%
feature_columns = ["neighbourhood_group", "room_type", "price", "minimum_nights", "calculated_host_listings_count", "availability_365"]
all_data = df[feature_columns]
all_data.head()
# Out:
#    neighbourhood_group        room_type  price  minimum_nights  \
# 0             Brooklyn     Private room    149               1
# 1            Manhattan  Entire home/apt    225               1
# 5            Manhattan  Entire home/apt    200               3
# 10           Manhattan  Entire home/apt    135               5
# 18            Brooklyn  Entire home/apt     99               3
#
#     calculated_host_listings_count  availability_365
# 0                                6               365
# 1                                2               355
# 5                                1               129
# 10                               1                 6
# 18                               1                21

# %% [markdown]
# The goal of data cleaning, a critical stage in the data analysis process, is to correct or remove inaccurate, missing, or duplicate data from a dataset. An overview of data cleaning, its role in guaranteeing dependable results, and a number of studies aimed at refining and testing data cleaning techniques are given in this study.
